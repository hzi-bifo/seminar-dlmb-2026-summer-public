# %% [markdown]
# ### Importing libraries
#
# Common libraries (numpy, pandas) is very easy to import.
#
# Special libraries can be loadedd

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import torch
import scipy

# %%
# !pip install cartopy
import cartopy

# %% [markdown]
# Or...

# %%
# !apt-get install build-essential
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# build-essential is already the newest version (12.9ubuntu3).
# 0 upgraded, 0 newly installed, 0 to remove and 35 not upgraded.

# %% [markdown]
# ###Using data
#
# There are two ways to use data. The first one is to upload them directly to the workspace. The second one is to mount drive. This can be done with the following code.

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-11-91874b305a32> in <cell line: 2>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive/')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     127   )
#     128   if ephemeral:
# --> 129     _message.blocking_request(
#     130         'request_auth', request={'authType': 'dfs_ephemeral'}, timeout_sec=None
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Code from the workspace can be loaded by copying the path of that file

# %%
data = pd.read_csv('',sep='')

# %% [markdown]
# ### Printing data
#
# Repeating the variable in the cell automatically prints the data

# %%
data

# %% [markdown]
# ### Hardware
# Access Runtime -> Change runtime type, and choose t4 GPU. There is no need to buy additional resources. This lasts for 12 hours. There are RAM and disk memory limitations, always bear in mind and aim for a memory friendly implementation. Check these resources on the top right corner.
#
# If memory fails, you might need to restart the session and run all the cells.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Download gpustat using pip as you saw before. Change the runtime type to t4 gpu and then run the command gpustat

# %%
# !pip install gpustat
# !gpustat
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.1/98.1 kB 1.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.4/58.4 kB 4.6 MB/s eta 0:00:00
# ...
#   Created wheel for gpustat: filename=gpustat-1.1.1-py3-none-any.whl size=26535 sha256=41c141b8014314ed09d9377c8aefd473c4be842571dfcd0fd65fcff8f075d8ea
#   Stored in directory: /root/.cache/pip/wheels/ec/d7/80/a71ba3540900e1f276bcae685efd8e590c810d2108b95f1e47
# Successfully built gpustat
# ...
# ad1b02441e6f  Wed Feb 28 10:41:52 2024  535.104.05
# [0] Tesla T4 | 37°C,   0 % |     0 / 15360 MB |

# %%
from platform import python_version
import torch
print("Python version", python_version())
print("Pytorch - version", torch.__version__)
print("Pytorch - cuDNN version :", torch.backends.cudnn.version())
# Out:
# Python version 3.10.12
# Pytorch - version 2.1.0+cu121
# Pytorch - cuDNN version : 8902

# %% [markdown]
# Colab supports 2 kinds of cells, code and text. Add text comments to clarify what you are doing and why.
